# %% [markdown]
# <h1 align=center> Exploratory Data Analysis

# %% [markdown]
# ### New York City Taxi trip Records

# %% [markdown]
# A partir de la data preprocesada de nulos, duplicados y outliers, se realiza un análisis inicial de la data disponible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# cargamos la data de viajes de Taxis Verdes en Diciembre 2019

# %%
df = pd.read_parquet(r'C:\Users\migue\Downloads\green_tripdata_2019-12.parquet', engine='pyarrow')
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              1  2019-12-01 00:09:45   2019-12-01 00:10:59
# 1              2  2019-12-01 00:26:05   2019-12-01 00:31:30
# 2              2  2019-12-01 00:56:36   2019-12-01 00:59:38
# 3              2  2019-12-01 00:26:20   2019-12-01 00:40:19
# 4              2  2019-12-01 00:56:36   2019-12-01 00:59:56
# ...          ...                  ...                   ...
# 455289         2  2019-12-31 23:24:00   2019-12-31 23:40:00
# 455290         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 455291         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 455292         2  2019-12-31 23:52:00   2020-01-01 00:05:00
# 455293         2  2019-12-31 23:52:00   2020-01-01 00:05:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           145           145
# 1                       N         1.0            24            41
# 2                       N         1.0            74            41
# 3                       N         1.0           255           157
# 4                       N         1.0            80           255
# ...                   ...         ...           ...           ...
# 455289               None         NaN           185           247
# 455290               None         NaN            51           126
# 455291               None         NaN            51           126
# 455292               None         NaN            42           244
# 455293               None         NaN            42           244
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                   1.0           0.00         3.00   0.50      0.5
# 1                   1.0           0.67         5.50   0.50      0.5
# 2                   1.0           0.61         4.50   0.50      0.5
# 3                   1.0           3.90        14.00   0.50      0.5
# 4                   1.0           0.50         4.50   0.50      0.5
# ...                 ...            ...          ...    ...      ...
# 455289              NaN           9.35        22.09   0.00      0.0
# 455290              NaN          -7.16        35.95   2.75      0.5
# 455291              NaN          -7.16        16.87   0.00      0.5
# 455292              NaN           2.43        21.15   2.75      0.5
# 455293              NaN           2.43         8.00   0.00      0.5
#
#         tip_amount  tolls_amount ehail_fee  improvement_surcharge  \
# 0             0.00           0.0      None                    0.3
# 1             2.04           0.0      None                    0.3
# 2             0.00           0.0      None                    0.3
# 3             0.00           0.0      None                    0.3
# 4             0.00           0.0      None                    0.3
# ...            ...           ...       ...                    ...
# 455289        0.00           0.0      None                    0.3
# 455290        0.00           0.0      None                    0.3
# 455291        0.00           0.0      None                    0.3
# 455292        0.00           0.0      None                    0.0
# 455293        0.00           0.0      None                    0.0
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0               4.30           2.0        1.0                   0.0
# 1               8.84           1.0        1.0                   0.0
# 2               5.80           2.0        1.0                   0.0
# 3              15.30           2.0        1.0                   0.0
# 4               5.80           2.0        1.0                   0.0
# ...              ...           ...        ...                   ...
# 455289         22.39           NaN        NaN                   NaN
# 455290         39.50           NaN        NaN                   NaN
# 455291         17.67           NaN        NaN                   NaN
# 455292         24.40           NaN        NaN                   NaN
# 455293          8.50           NaN        NaN                   NaN
#
# [455294 rows x 20 columns]

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['day'] = df['lpep_pickup_datetime'].dt.day_name()
df['hour'] = df['lpep_pickup_datetime'].dt.hour
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              1  2019-12-01 00:09:45   2019-12-01 00:10:59
# 1              2  2019-12-01 00:26:05   2019-12-01 00:31:30
# 2              2  2019-12-01 00:56:36   2019-12-01 00:59:38
# 3              2  2019-12-01 00:26:20   2019-12-01 00:40:19
# 4              2  2019-12-01 00:56:36   2019-12-01 00:59:56
# ...          ...                  ...                   ...
# 455289         2  2019-12-31 23:24:00   2019-12-31 23:40:00
# 455290         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 455291         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 455292         2  2019-12-31 23:52:00   2020-01-01 00:05:00
# 455293         2  2019-12-31 23:52:00   2020-01-01 00:05:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           145           145
# 1                       N         1.0            24            41
# 2                       N         1.0            74            41
# 3                       N         1.0           255           157
# 4                       N         1.0            80           255
# ...                   ...         ...           ...           ...
# 455289               None         NaN           185           247
# 455290               None         NaN            51           126
# 455291               None         NaN            51           126
# 455292               None         NaN            42           244
# 455293               None         NaN            42           244
#
#         passenger_count  trip_distance  fare_amount  ...  tip_amount  \
# 0                   1.0           0.00         3.00  ...        0.00
# 1                   1.0           0.67         5.50  ...        2.04
# 2                   1.0           0.61         4.50  ...        0.00
# 3                   1.0           3.90        14.00  ...        0.00
# 4                   1.0           0.50         4.50  ...        0.00
# ...                 ...            ...          ...  ...         ...
# 455289              NaN           9.35        22.09  ...        0.00
# 455290              NaN          -7.16        35.95  ...        0.00
# 455291              NaN          -7.16        16.87  ...        0.00
# 455292              NaN           2.43        21.15  ...        0.00
# 455293              NaN           2.43         8.00  ...        0.00
#
#         tolls_amount  ehail_fee  improvement_surcharge total_amount  \
# 0                0.0       None                    0.3         4.30
# 1                0.0       None                    0.3         8.84
# 2                0.0       None                    0.3         5.80
# 3                0.0       None                    0.3        15.30
# 4                0.0       None                    0.3         5.80
# ...              ...        ...                    ...          ...
# 455289           0.0       None                    0.3        22.39
# 455290           0.0       None                    0.3        39.50
# 455291           0.0       None                    0.3        17.67
# 455292           0.0       None                    0.0        24.40
# 455293           0.0       None                    0.0         8.50
#
#         payment_type  trip_type  congestion_surcharge      day  hour
# 0                2.0        1.0                   0.0   Sunday     0
# 1                1.0        1.0                   0.0   Sunday     0
# 2                2.0        1.0                   0.0   Sunday     0
# 3                2.0        1.0                   0.0   Sunday     0
# 4                2.0        1.0                   0.0   Sunday     0
# ...              ...        ...                   ...      ...   ...
# 455289           NaN        NaN                   NaN  Tuesday    23
# 455290           NaN        NaN                   NaN  Tuesday    23
# 455291           NaN        NaN                   NaN  Tuesday    23
# 455292           NaN        NaN                   NaN  Tuesday    23
# 455293           NaN        NaN                   NaN  Tuesday    23
#
# [455294 rows x 22 columns]

# %%
# Crear una tabla pivote con las horas como filas, los días de la semana como columnas y el conteo de registros como valores
pivot_table = df.pivot_table(index='hour', columns='day', aggfunc='size', fill_value=0)

# Ordenar las columnas de la tabla pivote para que los días estén en el orden correcto
ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
pivot_table = pivot_table[ordered_days]

# Crear el heatmap usando seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt='d')
plt.title('Heatmap de Demanda de Taxi por día y hora')
plt.xlabel('día de la semana')
plt.ylabel('hora del dia')
plt.show()

# %% [markdown]
# Observamos que la mayor demanda de taxis verdes se produce los días Lunes y Martes entre las 16 y 18 hrs. Tambien algunos viajes Viernes y Sabado cercano a medianoche y muy baja demanda antes de las 6 am

# %%
df1 = pd.read_parquet(r'C:\Users\migue\Downloads\yellow_tripdata_2019-12.parquet', engine='pyarrow')
df1.shape[0]
# Out:
# 6896317

# %% [markdown]
# Considerando que en el mes de Diciembre se registraron 6896317 de viajes en taxis Amarillos y 455294 viajes en Taxis Verdes, podemos graficar su distribución respecto al total de demanda de Taxis

# %%
values = [6896317, 455294]
labels = ['Yellow Taxi', 'Green Taxi']

# Función para mostrar tanto el porcentaje como el valor absoluto
def autopct_format(values):
    def inner_autopct(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({val:,})'
    return inner_autopct

# Crear el gráfico de torta
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct=autopct_format(values), startangle=90, colors=['gold', 'green'])

# Añadir un título
plt.title('Distribución de Yellow Taxi y Green Taxi')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Observamos que los viajes en Taxi Verde constituyen un 6.2% de los viajes en Taxis durante ese período

# %% [markdown]
# Analizaremos la cantidad de viajes por Borough, para esto debemos abrir y merge con el dataset 'Service Zones'

# %%
df1 = pd.read_csv(r'C:\Users\migue\OneDrive\Escritorio\Dataset Taxis\data_limpia\Service Zones.csv')
df1
# Out:
#      LocationID        Borough                     Zone service_zone  \
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 258         259          Bronx       Woodlawn/Wakefield    Boro Zone
# 259         260         Queens                 Woodside    Boro Zone
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
#
#      Shape_Leng  Shape_Area
# 0      0.116357    0.000782
# 1      0.433470    0.004866
# 2      0.084341    0.000314
# 3      0.043567    0.000112
# 4      0.092146    0.000498
# ..          ...         ...
# 258    0.126750    0.000395
# 259    0.133514    0.000422
# 260    0.027120    0.000034
# 261    0.049064    0.000122
# 262    0.037017    0.000066
#
# [263 rows x 6 columns]

# %% [markdown]
# dejamos solo columnas de interés para el merge

# %%
columnas = ['LocationID', 'Borough', 'Zone']
df1 = df1[columnas]
df1
# Out:
#      LocationID        Borough                     Zone
# 0             1            EWR           Newark Airport
# 1             2         Queens              Jamaica Bay
# 2             3          Bronx  Allerton/Pelham Gardens
# 3             4      Manhattan            Alphabet City
# 4             5  Staten Island            Arden Heights
# ..          ...            ...                      ...
# 258         259          Bronx       Woodlawn/Wakefield
# 259         260         Queens                 Woodside
# 260         261      Manhattan       World Trade Center
# 261         262      Manhattan           Yorkville East
# 262         263      Manhattan           Yorkville West
#
# [263 rows x 3 columns]

# %% [markdown]
# realizamos el merge

# %%
df = pd.merge(df, df1, left_on='PULocationID', right_on='LocationID', how='left')
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              1  2019-12-01 00:09:45   2019-12-01 00:10:59
# 1              2  2019-12-01 00:26:05   2019-12-01 00:31:30
# 2              2  2019-12-01 00:56:36   2019-12-01 00:59:38
# 3              2  2019-12-01 00:26:20   2019-12-01 00:40:19
# 4              2  2019-12-01 00:56:36   2019-12-01 00:59:56
# ...          ...                  ...                   ...
# 456571         2  2019-12-31 23:24:00   2019-12-31 23:40:00
# 456572         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 456573         2  2019-12-31 23:16:00   2019-12-31 23:37:00
# 456574         2  2019-12-31 23:52:00   2020-01-01 00:05:00
# 456575         2  2019-12-31 23:52:00   2020-01-01 00:05:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           145           145
# 1                       N         1.0            24            41
# 2                       N         1.0            74            41
# 3                       N         1.0           255           157
# 4                       N         1.0            80           255
# ...                   ...         ...           ...           ...
# 456571               None         NaN           185           247
# 456572               None         NaN            51           126
# 456573               None         NaN            51           126
# 456574               None         NaN            42           244
# 456575               None         NaN            42           244
#
#         passenger_count  trip_distance  fare_amount  ...  \
# 0                   1.0           0.00         3.00  ...
# 1                   1.0           0.67         5.50  ...
# 2                   1.0           0.61         4.50  ...
# 3                   1.0           3.90        14.00  ...
# 4                   1.0           0.50         4.50  ...
# ...                 ...            ...          ...  ...
# 456571              NaN           9.35        22.09  ...
# 456572              NaN          -7.16        35.95  ...
# 456573              NaN          -7.16        16.87  ...
# 456574              NaN           2.43        21.15  ...
# 456575              NaN           2.43         8.00  ...
#
#         improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                         0.3          4.30           2.0        1.0
# 1                         0.3          8.84           1.0        1.0
# 2                         0.3          5.80           2.0        1.0
# 3                         0.3         15.30           2.0        1.0
# 4                         0.3          5.80           2.0        1.0
# ...                       ...           ...           ...        ...
# 456571                    0.3         22.39           NaN        NaN
# 456572                    0.3         39.50           NaN        NaN
# 456573                    0.3         17.67           NaN        NaN
# 456574                    0.0         24.40           NaN        NaN
# 456575                    0.0          8.50           NaN        NaN
#
#        congestion_surcharge      day  hour  LocationID    Borough  \
# 0                       0.0   Sunday     0       145.0     Queens
# 1                       0.0   Sunday     0        24.0  Manhattan
# 2                       0.0   Sunday     0        74.0  Manhattan
# 3                       0.0   Sunday     0       255.0   Brooklyn
# 4                       0.0   Sunday     0        80.0   Brooklyn
# ...                     ...      ...   ...         ...        ...
# 456571                  NaN  Tuesday    23       185.0      Bronx
# 456572                  NaN  Tuesday    23        51.0      Bronx
# 456573                  NaN  Tuesday    23        51.0      Bronx
# 456574                  NaN  Tuesday    23        42.0  Manhattan
# 456575                  NaN  Tuesday    23        42.0  Manhattan
#
#                                   Zone
# 0       Long Island City/Hunters Point
# 1                         Bloomingdale
# 2                    East Harlem North
# 3            Williamsburg (North Side)
# 4                    East Williamsburg
# ...                                ...
# 456571                  Pelham Parkway
# 456572                      Co-Op City
# 456573                      Co-Op City
# 456574            Central Harlem North
# 456575            Central Harlem North
#
# [456576 rows x 25 columns]

# %% [markdown]
# Ahora podemos visualizar la cantidad de viajes de Taxis Verdes por Borough

# %%
borough_counts = df['Borough'].value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
borough_counts.plot(kind='bar', color='green')
plt.title('Viajes en Taxi Verde por Borough')
plt.xlabel('Borough')
plt.ylabel('Cantidad de viajes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Notamos que Manhattan lidera pero seguido sin tanta distancia por Queen y Brooklyn, tambien que Staten Island y EWR no poseen viajes Verdes
